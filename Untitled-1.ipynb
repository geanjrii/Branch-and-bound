# %%
from mip import *


def lerArquivo(nome_arquivo):
    with open(nome_arquivo, 'r') as arquivo:
        # Lê a primeira linha contendo o número de variáveis e restrições
        num_variaveis, num_restricoes = map(int, arquivo.readline().split())

        # Lê a segunda linha contendo os coeficientes da função objetivo
        coeficientes_objetivo = list(map(int, arquivo.readline().split()))

        # Lê as linhas restantes contendo as restrições
        restricoes = []
        for _ in range(num_restricoes):
            restricao = list(map(float, arquivo.readline().split()))
            restricoes.append(restricao)

    return num_variaveis, num_restricoes, coeficientes_objetivo, restricoes


def imprimirValoresLidos(nome_arquivo):
    num_variaveis, num_restricoes, coeficientes_objetivo, restricoes = lerArquivo(
        nome_arquivo)

    print("Número de variáveis:", num_variaveis)
    print("Número de restrições:", num_restricoes)
    print("Coeficientes da função objetivo:", coeficientes_objetivo)
    print("Restrições:")
    for restricao in restricoes:
        print(restricao)


def criarModelo(nome_arquivo):
    num_variaveis, num_restricoes, coeficientes_objetivo, restricoes = lerArquivo(
        nome_arquivo)

    # Cria o modelo
    model = Model()

    # Cria as variáveis de decisão binárias
    #variaveis = [model.add_var(var_type=BINARY) for _ in range(num_variaveis)]

    variaveis = [model.add_var() for _ in range(num_variaveis)]

    # Define a função objetivo
    model.objective = maximize(
        xsum(coeficientes_objetivo[i] * variaveis[i] for i in range(num_variaveis)))

    # Adiciona as restrições
    for restricao in restricoes:
        model.add_constr(xsum(restricao[i] * variaveis[i]
                         for i in range(num_variaveis)) <= restricao[-1])
    return model


def resolverModelo(nome_arquivo):
    model = criarModelo(nome_arquivo)

    model.write("model.lp")
    with open("model.lp") as f:
        print(f.read())

    status = model.optimize()

    if(status == OptimizationStatus.OPTIMAL):        
        print("Solução ótima")
    else:
        print("Status = ", status)

    print("Valor da solução:", model.objective_value)
    print("Solução:")
    for v in model.vars:
        if v.x > 0.00001:
            print('    ', v.name, " = ", v.x)

# %%
nome_arquivo = 'teste1.txt'
imprimirValoresLidos(nome_arquivo)
# Out:
# Número de variáveis: 7
# Número de restrições: 11
# Coeficientes da função objetivo: [2, 10, 8, 7, 10, 10, 6]
# Restrições:
# [5.0, 7.0, 8.0, 1.0, 7.0, 5.0, 6.0, 20.0]
# [1.0, 6.0, 4.0, 9.0, 10.0, 6.0, 10.0, 30.0]
# [4.0, 4.0, 4.0, 1.0, 5.0, 5.0, 10.0, 40.0]
# [3.0, 10.0, 8.0, 1.0, 3.0, 3.0, 8.0, 30.0]
# [10.0, 8.0, 9.0, 9.0, 7.0, 6.0, 10.0, 20.0]
# [6.0, 6.0, 3.0, 6.0, 3.0, 7.0, 2.0, 80.0]
# [7.0, 10.0, 7.0, 8.0, 7.0, 8.0, 7.0, 100.0]
# [9.0, 8.0, 1.0, 1.0, 8.0, 10.0, 2.0, 90.0]
# [1.0, 5.0, 3.0, 10.0, 2.0, 4.0, 9.0, 70.0]
# [9.0, 6.0, 1.0, 4.0, 7.0, 5.0, 10.0, 60.0]
# [5.0, 7.0, 4.0, 4.0, 3.0, 4.0, 10.0, 40.0]

# %%
nome_arquivo = 'teste1.txt'
resolverModelo(nome_arquivo)
# Out:
# \Problem name:
#
# Minimize
# OBJROW: -2 var(0) -10 var(1) -8 var(2) -7 var(3) -10 var(4) -10 var(5) -6 var(6)
# Subject To
# constr(0):  5 var(0) + 7 var(1) + 8 var(2) + var(3) + 7 var(4) + 5 var(5) + 6 var(6) <= 20
# constr(1):  var(0) + 6 var(1) + 4 var(2) + 9 var(3) + 10 var(4) + 6 var(5) + 10 var(6) <= 30
# constr(2):  4 var(0) + 4 var(1) + 4 var(2) + var(3) + 5 var(4) + 5 var(5) + 10 var(6) <= 40
# constr(3):  3 var(0) + 10 var(1) + 8 var(2) + var(3) + 3 var(4) + 3 var(5) + 8 var(6) <= 30
# constr(4):  10 var(0) + 8 var(1) + 9 var(2) + 9 var(3) + 7 var(4) + 6 var(5) + 10 var(6) <= 20
# constr(5):  6 var(0) + 6 var(1) + 3 var(2) + 6 var(3) + 3 var(4) + 7 var(5) + 2 var(6) <= 80
# constr(6):  7 var(0) + 10 var(1) + 7 var(2) + 8 var(3) + 7 var(4) + 8 var(5) + 7 var(6) <= 100
# constr(7):  9 var(0) + 8 var(1) + var(2) + var(3) + 8 var(4) + 10 var(5) + 2 var(6) <= 90
# constr(8):  var(0) + 5 var(1) + 3 var(2) + 10 var(3) + 2 var(4) + 4 var(5) + 9 var(6) <= 70
# constr(9):  9 var(0) + 6 var(1) + var(2) + 4 var(3) + 7 var(4) + 5 var(5) + 10 var(6) <= 60
# constr(10):  5 var(0) + 7 var(1) + 4 var(2) + 4 var(3) + 3 var(4) + 4 var(5) + 10 var(6) <= 40
# Bounds
#  0 <= var(0) <= 1
#  0 <= var(1) <= 1
#  0 <= var(2) <= 1
#  0 <= var(3) <= 1
#  0 <= var(4) <= 1
#  0 <= var(5) <= 1
#  0 <= var(6) <= 1
# Integers
# var(0) var(1) var(2) var(3) var(4) var(5) var(6)
# End
#
# Welcome to the CBC MILP Solver
# Version: Trunk
# Build Date: Oct 24 2021
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 4 (-7) rows, 7 (0) columns and 28 (-49) elements
# Clp1000I sum of infeasibilities 1.76961e-11 - average 4.42402e-12, 3 fixed columns
# Coin0506I Presolve 4 (0) rows, 4 (-3) columns and 16 (-12) elements
# Clp0029I End of values pass after 4 iterations
# Clp0000I Optimal - objective value 28.75
# Clp0000I Optimal - objective value 28.75
# Coin0511I After Postsolve, objective 28.75, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0000I Optimal - objective value 28.75
# Clp0000I Optimal - objective value 28.75
# Clp0000I Optimal - objective value 28.75
# Coin0511I After Postsolve, objective 28.75, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 28.75 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 4 rows, 7 columns (7 integer (7 of which binary)) and 28 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 6.667%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 3.1e-05
# Cbc0038I Initial state - 1 integers unsatisfied sum - 0.125
# Cbc0038I Pass   1: suminf.    0.12500 (1) obj. -28.75 iterations 0
# Cbc0038I Solution found of -20
# Cbc0038I Before mini branch and bound, 6 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 4 rows 7 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of -21.7749
# Cbc0038I Reduced cost fixing fixed 1 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.12500 (1) obj. -28.75 iterations 0
# Cbc0038I Pass   3: suminf.    0.17749 (1) obj. -21.7749 iterations 1
# Cbc0038I Pass   4: suminf.    0.17749 (1) obj. -21.7749 iterations 1
# Cbc0038I Pass   5: suminf.    0.17749 (1) obj. -21.7749 iterations 0
# Cbc0038I Pass   6: suminf.    0.40000 (1) obj. -23.6 iterations 2
# Cbc0038I Pass   7: suminf.    0.17749 (1) obj. -21.7749 iterations 2
# Cbc0038I Pass   8: suminf.    0.17749 (1) obj. -21.7749 iterations 0
# Cbc0038I Pass   9: suminf.    0.33333 (1) obj. -24.6667 iterations 2
# Cbc0038I Pass  10: suminf.    0.33333 (1) obj. -24.6667 iterations 0
# Cbc0038I Pass  11: suminf.    0.33333 (1) obj. -24.6667 iterations 0
# Cbc0038I Pass  12: suminf.    0.33333 (1) obj. -24.6667 iterations 0
# Cbc0038I Pass  13: suminf.    0.33333 (1) obj. -24.6667 iterations 0
# Cbc0038I Pass  14: suminf.    0.33333 (1) obj. -24.6667 iterations 0
# Cbc0038I Pass  15: suminf.    0.33333 (1) obj. -24.6667 iterations 0
# Cbc0038I Pass  16: suminf.    0.33333 (1) obj. -24.6667 iterations 0
# Cbc0038I Pass  17: suminf.    0.33333 (1) obj. -24.6667 iterations 0
# Cbc0038I Pass  18: suminf.    0.47749 (1) obj. -21.7749 iterations 2
# Cbc0038I Pass  19: suminf.    0.47749 (1) obj. -21.7749 iterations 0
# Cbc0038I Pass  20: suminf.    0.48593 (2) obj. -21.7749 iterations 1
# Cbc0038I Pass  21: suminf.    0.47749 (1) obj. -21.7749 iterations 1
# Cbc0038I Pass  22: suminf.    0.17749 (1) obj. -21.7749 iterations 2
# Cbc0038I Pass  23: suminf.    0.17749 (1) obj. -21.7749 iterations 0
# Cbc0038I Pass  24: suminf.    0.22222 (1) obj. -25.4444 iterations 3
# Cbc0038I Pass  25: suminf.    0.22222 (1) obj. -25.4444 iterations 0
# Cbc0038I Pass  26: suminf.    0.17749 (1) obj. -21.7749 iterations 2
# Cbc0038I Pass  27: suminf.    0.12500 (1) obj. -28.75 iterations 1
# Cbc0038I Pass  28: suminf.    0.12500 (1) obj. -28.75 iterations 0
# Cbc0038I Pass  29: suminf.    0.17749 (1) obj. -21.7749 iterations 2
# Cbc0038I Pass  30: suminf.    0.12500 (1) obj. -28.75 iterations 2
# Cbc0038I Pass  31: suminf.    0.17749 (1) obj. -21.7749 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 4 rows 7 columns, reduced to 3 rows 5 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -20 - took 0.00 seconds
# Cbc0012I Integer solution of -20 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0031I 2 added rows had average density of 4.5
# Cbc0013I At root node, 3 cuts changed objective from -28.75 to -20 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1 row cuts average 6.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 2 row cuts average 4.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -20, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 1 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solução ótima
# Valor da solução: 20.0
# Solução:
#      var(4)  =  1.0
#      var(5)  =  1.0

# %%
nome_arquivo = 'teste2.txt'
resolverModelo(nome_arquivo)
# Out:
# \Problem name:
#
# Minimize
# OBJROW: -7 var(0) -7 var(1) -7 var(2) -5 var(3) -8 var(4) -8 var(5) -9 var(6) -10 var(7) -7 var(8)
# Subject To
# constr(0):  var(0) + 3 var(1) + var(2) + 3 var(3) + 3 var(4) + 7 var(5) + 2 var(6) + var(7) + 4 var(8) <= 80
# constr(1):  7 var(0) + 6 var(1) + 10 var(2) + var(3) + 7 var(4) + 2 var(5) + 2 var(6) + 7 var(7) + var(8) <= 90
# constr(2):  3 var(0) + 2 var(1) + var(2) + 3 var(3) + 3 var(4) + 2 var(5) + var(6) + 6 var(7) + 5 var(8) <= 10
# constr(3):  10 var(0) + 8 var(1) + 3 var(2) + 6 var(3) + 10 var(4) + 7 var(5) + 3 var(6) + 10 var(7) + 4 var(8) <= 30
# constr(4):  2 var(0) + 8 var(1) + 6 var(2) + 5 var(3) + 6 var(4) + 6 var(5) + 9 var(6) + 7 var(7) + 2 var(8) <= 80
# constr(5):  3 var(0) + 10 var(1) + var(2) + 9 var(3) + 2 var(4) + 7 var(5) + 7 var(6) + 9 var(7) + 10 var(8) <= 90
# constr(6):  var(0) + 7 var(1) + 10 var(2) + 10 var(3) + 5 var(4) + 2 var(5) + 9 var(6) + 10 var(7) + 2 var(8) <= 20
# constr(7):  10 var(0) + 3 var(1) + 2 var(2) + 3 var(3) + 10 var(4) + 2 var(5) + var(6) + 9 var(7) + 7 var(8) <= 10
# constr(8):  2 var(0) + var(1) + 7 var(2) + 10 var(3) + var(4) + var(5) + 2 var(6) + var(7) + var(8) <= 50
# Bounds
#  0 <= var(0) <= 1
#  0 <= var(1) <= 1
#  0 <= var(2) <= 1
#  0 <= var(3) <= 1
#  0 <= var(4) <= 1
#  0 <= var(5) <= 1
#  0 <= var(6) <= 1
#  0 <= var(7) <= 1
#  0 <= var(8) <= 1
# Integers
# var(0) var(1) var(2) var(3) var(4) var(5) var(6) var(7) var(8)
# End
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 4 (-5) rows, 9 (0) columns and 36 (-45) elements
# Clp1000I sum of infeasibilities 6.69331e-12 - average 1.67333e-12, 3 fixed columns
# Coin0506I Presolve 4 (0) rows, 6 (-3) columns and 24 (-12) elements
# Clp0006I 0  Obj 28.454476 Dual inf 5215 (6)
# Clp0029I End of values pass after 6 iterations
# Clp0000I Optimal - objective value 28.454545
# Clp0000I Optimal - objective value 28.454545
# Coin0511I After Postsolve, objective 28.454545, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 28.454545
# Clp0000I Optimal - objective value 28.454545
# Clp0000I Optimal - objective value 28.454545
# Clp0000I Optimal - objective value 28.454545
# Coin0511I After Postsolve, objective 28.454545, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 28.45454545 - 0 iterations time 0.002, Presolve 0.00
#
# Starting MIP optimization
# Cgl0004I processed model has 4 rows, 9 columns (9 integer (9 of which binary)) and 36 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 16.959%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 4.2e-05
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.545455
# Cbc0038I Pass   1: suminf.    0.42857 (1) obj. -28 iterations 1
# Cbc0038I Solution found of -24
# Cbc0038I Before mini branch and bound, 7 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 4 rows 9 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of -25.3454
# Cbc0038I Reduced cost fixing fixed 3 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.42857 (1) obj. -28 iterations 0
# Cbc0038I Pass   3: suminf.    0.13454 (1) obj. -25.3454 iterations 2
# Cbc0038I Pass   4: suminf.    0.20000 (1) obj. -26 iterations 1
# Cbc0038I Pass   5: suminf.    0.45713 (2) obj. -25.3454 iterations 4
# Cbc0038I Pass   6: suminf.    0.80781 (2) obj. -25.3454 iterations 1
# Cbc0038I Pass   7: suminf.    0.62245 (2) obj. -26.6429 iterations 1
# Cbc0038I Pass   8: suminf.    0.36742 (2) obj. -25.3454 iterations 2
# Cbc0038I Pass   9: suminf.    0.36742 (2) obj. -25.3454 iterations 0
# Cbc0038I Pass  10: suminf.    0.45713 (2) obj. -25.3454 iterations 2
# Cbc0038I Pass  11: suminf.    0.80781 (2) obj. -25.3454 iterations 1
# Cbc0038I Pass  12: suminf.    0.62245 (2) obj. -26.6429 iterations 1
# Cbc0038I Pass  13: suminf.    0.36742 (2) obj. -25.3454 iterations 2
# Cbc0038I Pass  14: suminf.    0.36742 (2) obj. -25.3454 iterations 0
# Cbc0038I Pass  15: suminf.    0.45713 (2) obj. -25.3454 iterations 2
# Cbc0038I Pass  16: suminf.    0.80781 (2) obj. -25.3454 iterations 1
# Cbc0038I Pass  17: suminf.    0.62245 (2) obj. -26.6429 iterations 1
# Cbc0038I Pass  18: suminf.    0.36742 (2) obj. -25.3454 iterations 2
# Cbc0038I Pass  19: suminf.    0.36742 (2) obj. -25.3454 iterations 0
# Cbc0038I Pass  20: suminf.    0.45713 (2) obj. -25.3454 iterations 2
# Cbc0038I Pass  21: suminf.    0.80781 (2) obj. -25.3454 iterations 1
# Cbc0038I Pass  22: suminf.    0.62245 (2) obj. -26.6429 iterations 1
# Cbc0038I Pass  23: suminf.    0.36742 (2) obj. -25.3454 iterations 2
# Cbc0038I Pass  24: suminf.    0.36742 (2) obj. -25.3454 iterations 0
# Cbc0038I Pass  25: suminf.    0.45713 (2) obj. -25.3454 iterations 2
# Cbc0038I Pass  26: suminf.    0.80781 (2) obj. -25.3454 iterations 1
# Cbc0038I Pass  27: suminf.    0.62245 (2) obj. -26.6429 iterations 1
# Cbc0038I Pass  28: suminf.    0.36742 (2) obj. -25.3454 iterations 2
# Cbc0038I Pass  29: suminf.    0.36742 (2) obj. -25.3454 iterations 0
# Cbc0038I Pass  30: suminf.    0.45713 (2) obj. -25.3454 iterations 2
# Cbc0038I Pass  31: suminf.    0.80781 (2) obj. -25.3454 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 4 rows 9 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -24 - took 0.00 seconds
# Cbc0012I Integer solution of -24 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from -28.454545 to -28.454545 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -24, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 1 variables fixed on reduced cost
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Solução ótima
# Valor da solução: 24.0
# Solução:
#      var(1)  =  1.0
#      var(5)  =  1.0
#      var(6)  =  1.0

# %%
nome_arquivo = 'teste3.txt'
resolverModelo(nome_arquivo)
# Out:
# \Problem name:
#
# Minimize
# OBJROW: -7 var(0) -9 var(1) -10 var(2) -3 var(3) -6 var(4) - var(5) -9 var(6) -8 var(7) -8 var(8)
# Subject To
# constr(0):  2 var(0) + var(1) + 9 var(2) + 6 var(3) + 3 var(4) + 6 var(5) + 10 var(6) + 9 var(7) + var(8) <= 60
# constr(1):  8 var(0) + 6 var(1) + 6 var(2) + 5 var(3) + 2 var(4) + 2 var(5) + 4 var(6) + 3 var(7) + 6 var(8) <= 80
# constr(2):  8 var(0) + var(1) + 3 var(2) + 7 var(3) + var(4) + 4 var(5) + 8 var(6) + 3 var(7) + 4 var(8) <= 30
# constr(3):  6 var(0) + 3 var(1) + 9 var(2) + 5 var(3) + 9 var(4) + 6 var(5) + 9 var(6) + 9 var(7) + 6 var(8) <= 40
# constr(4):  10 var(0) + 8 var(1) + 8 var(2) + 7 var(3) + 10 var(4) + 10 var(5) + 9 var(6) + 9 var(7) + 3 var(8) <= 20
# constr(5):  10 var(0) + 10 var(1) + 10 var(2) + 9 var(3) + 10 var(4) + var(5) + 8 var(6) + 3 var(7) + 10 var(8) <= 90
# constr(6):  10 var(0) + 5 var(1) + 8 var(2) + 2 var(3) + 7 var(4) + 8 var(5) + 6 var(6) + 2 var(7) + 2 var(8) <= 90
# constr(7):  7 var(0) + 9 var(1) + var(2) + 9 var(3) + 5 var(4) + 8 var(5) + 5 var(6) + 9 var(7) + 5 var(8) <= 80
# constr(8):  2 var(0) + 4 var(1) + 6 var(2) + var(3) + 7 var(4) + 9 var(5) + 10 var(6) + var(7) + 7 var(8) <= 80
# constr(9):  8 var(0) + 10 var(1) + 2 var(2) + 6 var(3) + 7 var(4) + 2 var(5) + 2 var(6) + 4 var(7) + 9 var(8) <= 10
# constr(10):  10 var(0) + 9 var(1) + var(2) + 4 var(3) + 2 var(4) + 4 var(5) + 4 var(6) + 8 var(7) + 2 var(8) <= 30
# constr(11):  9 var(0) + 4 var(1) + var(2) + 8 var(3) + 9 var(4) + 5 var(5) + 10 var(6) + 5 var(7) + 8 var(8) <= 30
# Bounds
#  0 <= var(0) <= 1
#  0 <= var(1) <= 1
#  0 <= var(2) <= 1
#  0 <= var(3) <= 1
#  0 <= var(4) <= 1
#  0 <= var(5) <= 1
#  0 <= var(6) <= 1
#  0 <= var(7) <= 1
#  0 <= var(8) <= 1
# Integers
# var(0) var(1) var(2) var(3) var(4) var(5) var(6) var(7) var(8)
# End
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 6 (-6) rows, 9 (0) columns and 54 (-54) elements
# Clp1000I sum of infeasibilities 5.79092e-13 - average 9.65154e-14, 2 fixed columns
# Coin0506I Presolve 4 (-2) rows, 7 (-2) columns and 28 (-26) elements
# Clp0006I 0  Obj 24.912953 Dual inf 5463.8889 (7)
# Clp0029I End of values pass after 7 iterations
# Clp0000I Optimal - objective value 24.913043
# Clp0000I Optimal - objective value 24.913043
# Coin0511I After Postsolve, objective 24.913043, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 24.913043
# Clp0000I Optimal - objective value 24.913043
# Clp0000I Optimal - objective value 24.913043
# Clp0000I Optimal - objective value 24.913043
# Coin0511I After Postsolve, objective 24.913043, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 24.91304348 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0004I processed model has 6 rows, 9 columns (9 integer (9 of which binary)) and 54 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 16.959%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 0.000126
# Cbc0038I Initial state - 1 integers unsatisfied sum - 0.333333
# Cbc0038I Solution found of -19
# Cbc0038I Before mini branch and bound, 8 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 6 rows 9 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of -20.1666
# Cbc0038I Reduced cost fixing fixed 7 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.14582 (1) obj. -20.1666 iterations 1
# Cbc0038I Pass   2: suminf.    0.33333 (1) obj. -21.6667 iterations 1
# Cbc0038I Pass   3: suminf.    0.33333 (1) obj. -21.6667 iterations 0
# Cbc0038I Pass   4: suminf.    0.14582 (1) obj. -20.1666 iterations 1
# Cbc0038I Pass   5: suminf.    0.33333 (1) obj. -21.6667 iterations 1
# Cbc0038I Pass   6: suminf.    0.33333 (1) obj. -21.6667 iterations 0
# Cbc0038I Pass   7: suminf.    0.14582 (1) obj. -20.1666 iterations 1
# Cbc0038I Pass   8: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass   9: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass  10: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass  11: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass  12: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass  13: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass  14: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass  15: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass  16: suminf.    0.24073 (1) obj. -20.1666 iterations 1
# Cbc0038I Pass  17: suminf.    0.24073 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass  18: suminf.    0.14582 (1) obj. -20.1666 iterations 1
# Cbc0038I Pass  19: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass  20: suminf.    0.33333 (1) obj. -21.6667 iterations 1
# Cbc0038I Pass  21: suminf.    0.14582 (1) obj. -20.1666 iterations 1
# Cbc0038I Pass  22: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass  23: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass  24: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass  25: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass  26: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass  27: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass  28: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass  29: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I Pass  30: suminf.    0.14582 (1) obj. -20.1666 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 6 rows 9 columns, reduced to 1 rows 2 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -19 - took 0.00 seconds
# Cbc0012I Integer solution of -19 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from -21.666667 to -21.666667 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -19, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 7 variables fixed on reduced cost
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Solução ótima
# Valor da solução: 19.0
# Solução:
#      var(2)  =  1.0
#      var(6)  =  1.0

# %%
nome_arquivo = 'teste4.txt'
resolverModelo(nome_arquivo)
# Out:
# \Problem name:
#
# Minimize
# OBJROW: -9 var(0) -7 var(1) -10 var(2) -7 var(3) -9 var(4) -6 var(5) -8 var(6) -4 var(7) -9 var(8)
# Subject To
# constr(0):  4 var(0) + 9 var(1) + 4 var(2) + var(3) + 9 var(4) + 6 var(5) + 3 var(6) + 6 var(7) + var(8) <= 40
# constr(1):  3 var(0) + 7 var(1) + 8 var(2) + 7 var(3) + 6 var(4) + 3 var(5) + 5 var(6) + 9 var(7) + 4 var(8) <= 80
# constr(2):  9 var(0) + 3 var(1) + 6 var(2) + 5 var(3) + 7 var(4) + var(5) + var(6) + 3 var(7) + 9 var(8) <= 40
# constr(3):  5 var(0) + 9 var(1) + 6 var(2) + 5 var(3) + 9 var(4) + 7 var(5) + 8 var(6) + 7 var(7) + 8 var(8) <= 10
# constr(4):  7 var(0) + 7 var(1) + 4 var(2) + var(3) + 3 var(4) + 4 var(5) + 8 var(6) + var(7) + 9 var(8) <= 10
# constr(5):  var(0) + 6 var(1) + 6 var(2) + var(3) + 6 var(4) + 7 var(5) + 3 var(6) + 8 var(7) + 7 var(8) <= 10
# constr(6):  6 var(0) + 6 var(1) + 8 var(2) + 6 var(3) + 10 var(4) + 8 var(5) + var(6) + 4 var(7) + 4 var(8) <= 70
# constr(7):  9 var(0) + var(1) + 9 var(2) + 7 var(3) + 10 var(4) + 5 var(5) + 6 var(6) + 2 var(7) + 5 var(8) <= 10
# constr(8):  2 var(0) + 7 var(1) + 6 var(2) + 5 var(3) + var(4) + var(5) + 9 var(6) + 2 var(7) + var(8) <= 20
# Bounds
#  0 <= var(0) <= 1
#  0 <= var(1) <= 1
#  0 <= var(2) <= 1
#  0 <= var(3) <= 1
#  0 <= var(4) <= 1
#  0 <= var(5) <= 1
#  0 <= var(6) <= 1
#  0 <= var(7) <= 1
#  0 <= var(8) <= 1
# Integers
# var(0) var(1) var(2) var(3) var(4) var(5) var(6) var(7) var(8)
# End
#
# Starting solution of the Linear programming relaxation problem using Primal Simplex
#
# Coin0506I Presolve 7 (-2) rows, 9 (0) columns and 63 (-18) elements
# Clp1000I sum of infeasibilities 0 - average 0, 2 fixed columns
# Coin0506I Presolve 5 (-2) rows, 7 (-2) columns and 35 (-28) elements
# Clp0006I 0  Obj 13.558938 Dual inf 5600 (7)
# Clp0029I End of values pass after 7 iterations
# Clp0000I Optimal - objective value 13.571429
# Clp0000I Optimal - objective value 13.571429
# Coin0511I After Postsolve, objective 13.571429, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 13.571429
# Clp0000I Optimal - objective value 13.571429
# Clp0000I Optimal - objective value 13.571429
# Clp0000I Optimal - objective value 13.571429
# Coin0511I After Postsolve, objective 13.571429, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 13.57142857 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
#
# Starting MIP optimization
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 5 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 5 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 5 strengthened rows, 0 substitutions
# Cgl0004I processed model has 7 rows, 9 columns (9 integer (9 of which binary)) and 63 elements
# Coin3009W Conflict graph built in 0.000 seconds, density: 26.316%
# Cgl0015I Clique Strengthening extended 0 cliques, 0 were dominated
# Cbc0045I Nauty did not find any useful orbits in time 2.9e-05
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -10
# Cbc0038I Before mini branch and bound, 9 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -10 - took 0.00 seconds
# Cbc0012I Integer solution of -10 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -10, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Solução ótima
# Valor da solução: 10.0
# Solução:
#      var(2)  =  1.0

# %%
def resolverModelo(model):
    status = model.optimize()

    if status == OptimizationStatus.OPTIMAL:
        print("Solução ótima")
        print("Valor da solução:", model.objective_value)
        print("Solução:")
        for v in model.vars:
            if v.x > 0.00001:
                print('    ', v.name, " = ", v.x)
    else:
        print("Status =", status)

    return status

def branchAndBound(model):
    pilha = [(model, 0)]  # Adicionamos um contador para rastrear os nós visitados
    melhor_solucao = None
    melhor_valor = float('-inf')

    while pilha:
        model, nivel = pilha.pop()
        print("Nível:", nivel)

        status = resolverModelo(model)

        if status == OptimizationStatus.OPTIMAL:
            valor_objetivo = model.objective_value
            variaveis_binarias = []

            for v in model.vars:
                if v.x is not None and (v.x == 0 or v.x == 1):
                    variaveis_binarias.append(v)

            if valor_objetivo > melhor_valor and len(variaveis_binarias) == len(model.vars):
                melhor_solucao = variaveis_binarias
                melhor_valor = valor_objetivo

        # Encontra a variável fracionária mais próxima de 0.5
        variavel_frac = None
        valor_frac = None

        for v in model.vars:
            valor = v.x
            if valor is not None and valor % 1 != 0 and (valor_frac is None or abs(valor - 0.5) < abs(valor_frac - 0.5)):
                variavel_frac = v
                valor_frac = valor

        if variavel_frac is None:
            continue

        # Cria os dois nós filhos com restrições adicionais
        model1 = model.copy()
        model2 = model.copy()

        model1.add_constr(variavel_frac == 1)
        model2.add_constr(variavel_frac == 0)

        pilha.append((model1, nivel + 1))
        pilha.append((model2, nivel + 1))

    if melhor_solucao is not None:
        print("Melhor solução encontrada:")
        for v in melhor_solucao:
            print('    ', v.name, " = ", v.x)
        print("Valor da solução:", melhor_valor)
    else:
        print("Nenhuma solução inteira encontrada.")

nome_arquivo = 'teste4.txt'
model = criarModelo(nome_arquivo)
branchAndBound(model)
# Out:
# Nível: 0
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 8 (-1) rows, 9 (0) columns and 72 (-9) elements
# Clp1000I sum of infeasibilities 0 - average 0, 0 fixed columns
# Coin0506I Presolve 8 (0) rows, 9 (0) columns and 72 (0) elements
# Clp0006I 0  Obj 13.571263 Dual inf 7296.8254 (9)
# Clp0029I End of values pass after 9 iterations
# Clp0000I Optimal - objective value 13.571429
# Clp0000I Optimal - objective value 13.571429
# Clp0000I Optimal - objective value 13.571429
# Coin0511I After Postsolve, objective 13.571429, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 13.57142857 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 13.571428571428573
# Solução:
#      var(2)  =  0.7142857142857143
#      var(8)  =  0.7142857142857144
# Nível: 1
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 8 (-2) rows, 8 (-1) columns and 64 (-18) elements
# Clp1000I sum of infeasibilities 0 - average 0, 4 fixed columns
# Coin0506I Presolve 7 (-1) rows, 4 (-4) columns and 28 (-36) elements
# Clp0006I 0  Obj 13.076817 Dual inf 3200 (4)
# Clp0029I End of values pass after 4 iterations
# Clp0000I Optimal - objective value 13.076923
# Clp0000I Optimal - objective value 13.076923
# Coin0511I After Postsolve, objective 13.076923, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 13.076923
# Clp0000I Optimal - objective value 13.076923
# Clp0000I Optimal - objective value 13.076923
# Clp0000I Optimal - objective value 13.076923
# Coin0511I After Postsolve, objective 13.076923, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 13.07692308 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 13.076923076923077
# Solução:
#      var(0)  =  0.3846153846153844
#      var(3)  =  0.3846153846153847
#      var(8)  =  0.7692307692307694
# Nível: 2
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 8 (-3) rows, 7 (-2) columns and 56 (-27) elements
# Clp1000I sum of infeasibilities 0 - average 0, 1 fixed columns
# Coin0506I Presolve 7 (-1) rows, 6 (-1) columns and 42 (-14) elements
# Clp0006I 0  Obj 12.688119 Dual inf 4385.7143 (6)
# Clp0029I End of values pass after 6 iterations
# Clp0000I Optimal - objective value 12.688172
# Clp0000I Optimal - objective value 12.688172
# Coin0511I After Postsolve, objective 12.688172, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 12.688172
# Clp0000I Optimal - objective value 12.688172
# Clp0000I Optimal - objective value 12.688172
# Clp0000I Optimal - objective value 12.688172
# Coin0511I After Postsolve, objective 12.688172, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 12.68817204 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 12.688172043010752
# Solução:
#      var(0)  =  1.021505376344086
#      var(1)  =  0.37634408602150554
#      var(7)  =  0.21505376344086008
# Nível: 3
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-5) rows, 6 (-3) columns and 42 (-42) elements
# Clp1000I sum of infeasibilities 0 - average 0, 1 fixed columns
# Coin0506I Presolve 7 (0) rows, 5 (-1) columns and 35 (-7) elements
# Clp0006I 0  Obj 12.558848 Dual inf 4000 (5)
# Clp0029I End of values pass after 5 iterations
# Clp0000I Optimal - objective value 12.558923
# Clp0000I Optimal - objective value 12.558923
# Coin0511I After Postsolve, objective 12.558923, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 12.558923
# Clp0000I Optimal - objective value 12.558923
# Clp0000I Optimal - objective value 12.558923
# Clp0000I Optimal - objective value 12.558923
# Coin0511I After Postsolve, objective 12.558923, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 12.55892256 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 12.558922558922559
# Solução:
#      var(0)  =  0.7744107744107743
#      var(7)  =  0.33670033670033667
#      var(8)  =  0.47138047138047157
# Nível: 4
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-6) rows, 5 (-4) columns and 35 (-50) elements
# Clp1000I sum of infeasibilities 0 - average 0, 0 fixed columns
# Coin0506I Presolve 6 (-1) rows, 5 (0) columns and 30 (-5) elements
# Clp0006I 0  Obj 11.799912 Dual inf 3685.7143 (5)
# Clp0029I End of values pass after 5 iterations
# Clp0000I Optimal - objective value 11.8
# Clp0000I Optimal - objective value 11.8
# Coin0511I After Postsolve, objective 11.8, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 11.8
# Clp0000I Optimal - objective value 11.8
# Clp0000I Optimal - objective value 11.8
# Clp0000I Optimal - objective value 11.8
# Coin0511I After Postsolve, objective 11.8, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 11.8 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 11.8
# Solução:
#      var(0)  =  0.5999999999999999
#      var(6)  =  0.7000000000000001
#      var(7)  =  0.20000000000000015
# Nível: 5
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-7) rows, 4 (-5) columns and 28 (-58) elements
# Clp1000I sum of infeasibilities 0 - average 0, 1 fixed columns
# Coin0506I Presolve 5 (-2) rows, 3 (-1) columns and 15 (-13) elements
# Clp0006I 0  Obj 9.9999552 Dual inf 2300 (3)
# Clp0029I End of values pass after 3 iterations
# Clp0000I Optimal - objective value 10
# Clp0000I Optimal - objective value 10
# Coin0511I After Postsolve, objective 10, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 10
# Clp0000I Optimal - objective value 10
# Clp0000I Optimal - objective value 10
# Clp0000I Optimal - objective value 10
# Coin0511I After Postsolve, objective 10, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 10 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 10.0
# Solução:
#      var(4)  =  0.769230769230769
#      var(6)  =  0.38461538461538486
# Nível: 6
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-8) rows, 3 (-6) columns and 21 (-66) elements
# Clp1000I sum of infeasibilities 0 - average 0, 0 fixed columns
# Coin0506I Presolve 4 (-3) rows, 3 (0) columns and 12 (-9) elements
# Clp0006I 0  Obj 9.599971 Dual inf 1985.7143 (3)
# Clp0029I End of values pass after 3 iterations
# Clp0000I Optimal - objective value 9.6
# Clp0000I Optimal - objective value 9.6
# Coin0511I After Postsolve, objective 9.6, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 9.6
# Clp0000I Optimal - objective value 9.6
# Clp0000I Optimal - objective value 9.6
# Clp0000I Optimal - objective value 9.6
# Coin0511I After Postsolve, objective 9.6, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 9.6 - 0 iterations time 0.002, Presolve 0.00
# Solução ótima
# Valor da solução: 9.600000000000001
# Solução:
#      var(4)  =  0.7999999999999997
#      var(5)  =  0.40000000000000047
# Nível: 7
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-9) rows, 2 (-7) columns and 14 (-74) elements
# Clp1000I sum of infeasibilities 0 - average 0, 0 fixed columns
# Coin0506I Presolve 4 (-3) rows, 2 (0) columns and 8 (-6) elements
# Clp0006I 0  Obj 9.4230753 Dual inf 1300 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0000I Optimal - objective value 9.4230769
# Clp0000I Optimal - objective value 9.4230769
# Coin0511I After Postsolve, objective 9.4230769, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 9.4230769
# Clp0000I Optimal - objective value 9.4230769
# Clp0000I Optimal - objective value 9.4230769
# Clp0000I Optimal - objective value 9.4230769
# Coin0511I After Postsolve, objective 9.4230769, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 9.423076923 - 0 iterations time 0.002, Presolve 0.00
# Solução ótima
# Valor da solução: 9.423076923076922
# Solução:
#      var(4)  =  0.9615384615384613
#      var(7)  =  0.19230769230769265
# Nível: 8
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 0 (-17) rows, 0 (-9) columns and 0 (-89) elements
# Clp0000I Optimal - objective value 9
# Coin0511I After Postsolve, objective 9, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 9 - 0 iterations time 0.002, Presolve 0.00
# Solução ótima
# Valor da solução: 9.0
# Solução:
#      var(4)  =  1.0
# Nível: 8
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 0 (-17) rows, 0 (-9) columns and 0 (-89) elements
# Clp0000I Optimal - objective value 7
# Coin0511I After Postsolve, objective 7, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 7 - 0 iterations time 0.002, Presolve 0.00
# Solução ótima
# Valor da solução: 7.0
# Solução:
#      var(4)  =  0.3333333333333333
#      var(7)  =  1.0
# Nível: 9
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 0 (-18) rows, 0 (-9) columns and 0 (-90) elements
# Clp0000I Optimal - objective value 4
# Coin0511I After Postsolve, objective 4, infeasibilities - dual 0 (0), primal 0 (0)
# Solução ótima
# Valor da solução: 4.0
# Solução:
#      var(7)  =  1.0
# Nível: 9
# Clp0032I Optimal objective 4 - 0 iterations time 0.002, Presolve 0.00
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 11.067304 Primal inf 0.96266674 (5) Dual inf 2.7277778e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value 2.3333333
# Clp0032I PrimalInfeasible objective 2.333333333 - 6 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 7
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-9) rows, 2 (-7) columns and 14 (-74) elements
# Clp1000I sum of infeasibilities 0 - average 0, 0 fixed columns
# Coin0506I Presolve 3 (-4) rows, 2 (0) columns and 6 (-8) elements
# Clp0006I 0  Obj 8.999956 Dual inf 1300 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0000I Optimal - objective value 9
# Clp0000I Optimal - objective value 9
# Coin0511I After Postsolve, objective 9, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 9
# Clp0000I Optimal - objective value 9
# Clp0000I Optimal - objective value 9
# Clp0000I Optimal - objective value 9
# Coin0511I After Postsolve, objective 9, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 9 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 9.0
# Solução:
#      var(4)  =  0.3333333333333333
#      var(5)  =  1.0
# Nível: 8
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 0 (-17) rows, 0 (-9) columns and 0 (-89) elements
# Clp0000I Optimal - objective value 7.5
# Coin0511I After Postsolve, objective 7.5, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 7.5 - 0 iterations time 0.002, Presolve 0.00
# Solução ótima
# Valor da solução: 7.5
# Solução:
#      var(5)  =  1.0
#      var(7)  =  0.375
# Nível: 9
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 0 (-18) rows, 0 (-9) columns and 0 (-90) elements
# Clp0000I Optimal - objective value 6
# Coin0511I After Postsolve, objective 6, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 6 - 0 iterations time 0.002, Presolve 0.00
# Solução ótima
# Valor da solução: 6.0
# Solução:
#      var(5)  =  1.0
# Nível: 9
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 8.6756097 Primal inf 0.87757819 (4) Dual inf 1.4305556e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value -35
# Clp0032I PrimalInfeasible objective -35 - 8 iterations time 0.002
# Status = OptimizationStatus.INFEASIBLE
# Nível: 8
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 12.570245 Primal inf 1.0710515 (5) Dual inf 2.9027778e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value -20
# Clp0032I PrimalInfeasible objective -20 - 3 iterations time 0.002
# Status = OptimizationStatus.INFEASIBLE
# Nível: 6
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-8) rows, 3 (-6) columns and 21 (-66) elements
# Clp1000I sum of infeasibilities 1.24922e-11 - average 1.7846e-12, 2 fixed columns
# Coin0506I Presolve 0 (-7) rows, 0 (-3) columns and 0 (-21) elements
# Clp0000I Optimal - objective value 10
# Clp0000I Optimal - objective value 10
# Coin0511I After Postsolve, objective 10, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 10
# Clp0000I Optimal - objective value 10
# Clp0000I Optimal - objective value 10
# Clp0000I Optimal - objective value 10
# Coin0511I After Postsolve, objective 10, infeasibilities - dual 0 (0), primal 0 (0)
# Solução ótima
# Valor da solução: 10.0
# Solução:
#      var(4)  =  0.2222222222222222
#      var(6)  =  1.0
# Clp0032I Optimal objective 10 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Nível: 7
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-9) rows, 2 (-7) columns and 14 (-74) elements
# Clp1000I sum of infeasibilities 0 - average 0, 1 fixed columns
# Coin0506I Presolve 0 (-7) rows, 0 (-2) columns and 0 (-14) elements
# Clp0000I Optimal - objective value 9.7142857
# Clp0000I Optimal - objective value 9.7142857
# Coin0511I After Postsolve, objective 9.7142857, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 9.7142857
# Clp0000I Optimal - objective value 9.7142857
# Clp0000I Optimal - objective value 9.7142857
# Clp0000I Optimal - objective value 9.7142857
# Coin0511I After Postsolve, objective 9.7142857, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 9.714285714 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 9.714285714285714
# Solução:
#      var(5)  =  0.2857142857142857
#      var(6)  =  1.0
# Nível: 8
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 0 (-17) rows, 0 (-9) columns and 0 (-89) elements
# Clp0000I Optimal - objective value 9.1428571
# Coin0511I After Postsolve, objective 9.1428571, infeasibilities - dual 0 (0), primal 0 (0)
# Solução ótima
# Valor da solução: 9.142857142857142
# Solução:
#      var(6)  =  1.0
#      var(7)  =  0.2857142857142857
# Clp0032I Optimal objective 9.142857143 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Nível: 9
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 0 (-18) rows, 0 (-9) columns and 0 (-90) elements
# Clp0000I Optimal - objective value 8
# Coin0511I After Postsolve, objective 8, infeasibilities - dual 0 (0), primal 0 (0)
# Solução ótima
# Valor da solução: 8.0
# Solução:
#      var(6)  =  1.0
# Nível: 9
# Clp0032I Optimal objective 8 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 10.936822 Primal inf 0.59258697 (4) Dual inf 1.0416667e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value 3
# Clp0032I PrimalInfeasible objective 3 - 3 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 8
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 12.625402 Primal inf 0.6753012 (4) Dual inf 1e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value 5
# Clp0032I PrimalInfeasible objective 5 - 9 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 7
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 14.077542 Primal inf 1.1124175 (4) Dual inf 1.4888889e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value -25
# Clp0032I PrimalInfeasible objective -25 - 3 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 5
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-7) rows, 4 (-5) columns and 28 (-58) elements
# Clp1000I sum of infeasibilities 2.22045e-16 - average 3.17207e-17, 3 fixed columns
# Coin0506I Presolve 0 (-7) rows, 0 (-4) columns and 0 (-28) elements
# Clp0000I Optimal - objective value 11
# Clp0000I Optimal - objective value 11
# Coin0511I After Postsolve, objective 11, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 11
# Clp0000I Optimal - objective value 11
# Clp0000I Optimal - objective value 11
# Clp0000I Optimal - objective value 11
# Coin0511I After Postsolve, objective 11, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 11 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 11.0
# Solução:
#      var(0)  =  1.0
#      var(7)  =  0.5
# Nível: 6
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-8) rows, 3 (-6) columns and 21 (-66) elements
# Clp1000I sum of infeasibilities 0 - average 0, 0 fixed columns
# Coin0506I Presolve 4 (-3) rows, 3 (0) columns and 12 (-9) elements
# Clp0006I 0  Obj 10.333274 Dual inf 2471.4286 (3)
# Clp0029I End of values pass after 3 iterations
# Clp0000I Optimal - objective value 10.333333
# Clp0000I Optimal - objective value 10.333333
# Coin0511I After Postsolve, objective 10.333333, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 10.333333
# Clp0000I Optimal - objective value 10.333333
# Clp0000I Optimal - objective value 10.333333
# Clp0000I Optimal - objective value 10.333333
# Coin0511I After Postsolve, objective 10.333333, infeasibilities - dual 0 (0), primal 0 (0)
# Solução ótima
# Valor da solução: 10.333333333333334
# Solução:
#      var(0)  =  1.0
#      var(6)  =  0.16666666666666666
# Clp0032I Optimal objective 10.33333333 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Nível: 7
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-9) rows, 2 (-7) columns and 14 (-74) elements
# Clp1000I sum of infeasibilities 0 - average 0, 0 fixed columns
# Coin0506I Presolve 3 (-4) rows, 2 (0) columns and 6 (-8) elements
# Clp0006I 0  Obj 10.199979 Dual inf 1671.4286 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0000I Optimal - objective value 10.2
# Clp0000I Optimal - objective value 10.2
# Coin0511I After Postsolve, objective 10.2, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 10.2
# Clp0000I Optimal - objective value 10.2
# Clp0000I Optimal - objective value 10.2
# Clp0000I Optimal - objective value 10.2
# Coin0511I After Postsolve, objective 10.2, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 10.2 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 10.2
# Solução:
#      var(0)  =  1.0
#      var(5)  =  0.19999999999999998
# Nível: 8
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 0 (-17) rows, 0 (-9) columns and 0 (-89) elements
# Clp0000I Optimal - objective value 9.9
# Coin0511I After Postsolve, objective 9.9, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 9.9 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 9.9
# Solução:
#      var(0)  =  1.0
#      var(4)  =  0.1
# Nível: 9
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 0 (-18) rows, 0 (-9) columns and 0 (-90) elements
# Clp0000I Optimal - objective value 9
# Coin0511I After Postsolve, objective 9, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 9 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 9.0
# Solução:
#      var(0)  =  1.0
# Nível: 9
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 14.938045 Primal inf 1.08771 (4) Dual inf 1.4555556e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value -45
# Clp0032I PrimalInfeasible objective -45 - 7 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 8
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 13.849006 Primal inf 0.58186324 (5) Dual inf 1.9555556e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value 11.4
# Clp0032I PrimalInfeasible objective 11.4 - 2 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 7
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 14.572187 Primal inf 1.0162781 (5) Dual inf 2.6111111e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value 11.333333
# Clp0032I PrimalInfeasible objective 11.33333333 - 2 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 6
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 12.517681 Primal inf 0.30602769 (4) Dual inf 4.7777778e+11 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value 6
# Clp0032I PrimalInfeasible objective 6 - 6 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 4
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-6) rows, 5 (-4) columns and 35 (-50) elements
# Clp1000I sum of infeasibilities 0 - average 0, 2 fixed columns
# Coin0506I Presolve 4 (-3) rows, 3 (-2) columns and 12 (-23) elements
# Clp0006I 0  Obj 11.249993 Dual inf 1174.5042 (3)
# Clp0029I End of values pass after 3 iterations
# Clp0000I Optimal - objective value 11.25
# Clp0000I Optimal - objective value 11.25
# Coin0511I After Postsolve, objective 11.25, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 11.25
# Clp0000I Optimal - objective value 11.25
# Clp0000I Optimal - objective value 11.25
# Clp0000I Optimal - objective value 11.25
# Coin0511I After Postsolve, objective 11.25, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 11.25 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 11.25
# Solução:
#      var(0)  =  0.0625
#      var(4)  =  0.18749999999999997
#      var(8)  =  1.0
# Nível: 5
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-7) rows, 4 (-5) columns and 28 (-58) elements
# Clp1000I sum of infeasibilities 0 - average 0, 2 fixed columns
# Coin0506I Presolve 4 (-3) rows, 2 (-2) columns and 8 (-20) elements
# Clp0006I 0  Obj 10.840909 Dual inf 666.76666 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0000I Optimal - objective value 10.840909
# Clp0000I Optimal - objective value 10.840909
# Coin0511I After Postsolve, objective 10.840909, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 10.840909
# Clp0000I Optimal - objective value 10.840909
# Clp0000I Optimal - objective value 10.840909
# Clp0000I Optimal - objective value 10.840909
# Coin0511I After Postsolve, objective 10.840909, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 10.84090909 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 10.84090909090909
# Solução:
#      var(0)  =  0.11363636363636363
#      var(7)  =  0.20454545454545453
#      var(8)  =  1.0
# Nível: 6
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-8) rows, 3 (-6) columns and 21 (-66) elements
# Clp1000I sum of infeasibilities 0 - average 0, 1 fixed columns
# Coin0506I Presolve 4 (-3) rows, 2 (-1) columns and 8 (-13) elements
# Clp0006I 0  Obj 10.499982 Dual inf 789.89795 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0000I Optimal - objective value 10.5
# Clp0000I Optimal - objective value 10.5
# Coin0511I After Postsolve, objective 10.5, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 10.5
# Clp0000I Optimal - objective value 10.5
# Clp0000I Optimal - objective value 10.5
# Clp0000I Optimal - objective value 10.5
# Coin0511I After Postsolve, objective 10.5, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 10.5 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 10.5
# Solução:
#      var(5)  =  0.25
#      var(8)  =  1.0
# Nível: 7
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-9) rows, 2 (-7) columns and 14 (-74) elements
# Clp1000I sum of infeasibilities 0 - average 0, 0 fixed columns
# Coin0506I Presolve 4 (-3) rows, 2 (0) columns and 8 (-6) elements
# Clp0006I 0  Obj 10.28568 Dual inf 932.45553 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0000I Optimal - objective value 10.285714
# Clp0000I Optimal - objective value 10.285714
# Coin0511I After Postsolve, objective 10.285714, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 10.285714
# Clp0000I Optimal - objective value 10.285714
# Clp0000I Optimal - objective value 10.285714
# Clp0000I Optimal - objective value 10.285714
# Coin0511I After Postsolve, objective 10.285714, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 10.28571429 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 10.285714285714285
# Solução:
#      var(0)  =  0.14285714285714285
#      var(8)  =  1.0
# Nível: 8
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 0 (-17) rows, 0 (-9) columns and 0 (-89) elements
# Clp0000I Optimal - objective value 10
# Coin0511I After Postsolve, objective 10, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 10 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 10.0
# Solução:
#      var(6)  =  0.125
#      var(8)  =  1.0
# Nível: 9
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 0 (-18) rows, 0 (-9) columns and 0 (-90) elements
# Clp0000I Optimal - objective value 9
# Coin0511I After Postsolve, objective 9, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 9 - 0 iterations time 0.002, Presolve 0.00
# Solução ótima
# Valor da solução: 9.0
# Solução:
#      var(8)  =  1.0
# Nível: 9
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 13.931697 Primal inf 1.1435472 (4) Dual inf 1.6666667e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value -32
# Clp0032I PrimalInfeasible objective -32 - 6 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 8
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 15.366741 Primal inf 1.0153945 (5) Dual inf 2.6222222e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Status = OptimizationStatus.INFEASIBLE
# Nível: 7
# Clp0001I Primal infeasible - objective value -24
# Clp0032I PrimalInfeasible objective -24 - 7 iterations time 0.002, Idiot 0.00
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 12.823989 Primal inf 0.97262498 (5) Dual inf 2.8611111e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value -21
# Clp0032I PrimalInfeasible objective -21 - 6 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 6
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 11.097795 Primal inf 0.95427584 (4) Dual inf 1.5416667e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value 4
# Clp0032I PrimalInfeasible objective 4 - 7 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 5
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 14.913231 Primal inf 1.1328971 (6) Dual inf 4.3472222e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value -17
# Clp0032I PrimalInfeasible objective -17 - 11 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 3
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 8 (-4) rows, 6 (-3) columns and 48 (-36) elements
# Clp1000I sum of infeasibilities 0 - average 0, 5 fixed columns
# Coin0506I Presolve 0 (-8) rows, 0 (-6) columns and 0 (-48) elements
# Clp0000I Optimal - objective value 8.8
# Clp0000I Optimal - objective value 8.8
# Coin0511I After Postsolve, objective 8.8, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 8.8
# Clp0000I Optimal - objective value 8.8
# Clp0000I Optimal - objective value 8.8
# Clp0000I Optimal - objective value 8.8
# Coin0511I After Postsolve, objective 8.8, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 8.8 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 8.799999999999999
# Solução:
#      var(0)  =  0.19999999999999996
#      var(1)  =  1.0
# Nível: 4
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 8 (-5) rows, 5 (-4) columns and 40 (-45) elements
# Clp1000I sum of infeasibilities 0 - average 0, 2 fixed columns
# Coin0506I Presolve 4 (-4) rows, 3 (-2) columns and 12 (-28) elements
# Clp0006I 0  Obj 8.1249842 Dual inf 2700 (3)
# Clp0029I End of values pass after 3 iterations
# Clp0000I Optimal - objective value 8.125
# Clp0000I Optimal - objective value 8.125
# Coin0511I After Postsolve, objective 8.125, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 8.125
# Clp0000I Optimal - objective value 8.125
# Clp0000I Optimal - objective value 8.125
# Clp0000I Optimal - objective value 8.125
# Coin0511I After Postsolve, objective 8.125, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 8.125 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 8.125
# Solução:
#      var(1)  =  1.0
#      var(8)  =  0.125
# Nível: 5
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 8 (-6) rows, 4 (-5) columns and 32 (-54) elements
# Clp1000I sum of infeasibilities 0 - average 0, 0 fixed columns
# Coin0506I Presolve 2 (-6) rows, 3 (-1) columns and 6 (-26) elements
# Clp0006I 0  Obj 7.9999664 Dual inf 2571.4286 (3)
# Clp0029I End of values pass after 3 iterations
# Clp0000I Optimal - objective value 8
# Clp0000I Optimal - objective value 8
# Coin0511I After Postsolve, objective 8, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 8
# Clp0000I Optimal - objective value 8
# Clp0000I Optimal - objective value 8
# Clp0000I Optimal - objective value 8
# Coin0511I After Postsolve, objective 8, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 8 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 8.0
# Solução:
#      var(1)  =  1.0
#      var(4)  =  0.1111111111111111
# Nível: 6
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 8 (-7) rows, 3 (-6) columns and 24 (-63) elements
# Clp1000I sum of infeasibilities 0 - average 0, 1 fixed columns
# Coin0506I Presolve 2 (-6) rows, 2 (-1) columns and 4 (-20) elements
# Clp0006I 0  Obj 7.999994 Dual inf 1400 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0000I Optimal - objective value 8
# Clp0000I Optimal - objective value 8
# Coin0511I After Postsolve, objective 8, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 8
# Clp0000I Optimal - objective value 8
# Clp0000I Optimal - objective value 8
# Clp0000I Optimal - objective value 8
# Coin0511I After Postsolve, objective 8, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 8 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 8.0
# Solução:
#      var(1)  =  1.0
#      var(6)  =  0.125
# Nível: 7
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-9) rows, 2 (-7) columns and 14 (-74) elements
# Clp1000I sum of infeasibilities 0 - average 0, 1 fixed columns
# Coin0506I Presolve 0 (-7) rows, 0 (-2) columns and 0 (-14) elements
# Clp0000I Optimal - objective value 7.8571429
# Clp0000I Optimal - objective value 7.8571429
# Coin0511I After Postsolve, objective 7.8571429, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 7.8571429
# Clp0000I Optimal - objective value 7.8571429
# Clp0000I Optimal - objective value 7.8571429
# Clp0000I Optimal - objective value 7.8571429
# Coin0511I After Postsolve, objective 7.8571429, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 7.857142857 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 7.857142857142857
# Solução:
#      var(1)  =  1.0
#      var(5)  =  0.14285714285714285
# Nível: 8
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 0 (-17) rows, 0 (-9) columns and 0 (-89) elements
# Clp0000I Optimal - objective value 7.5714286
# Coin0511I After Postsolve, objective 7.5714286, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 7.571428571 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 7.571428571428571
# Solução:
#      var(1)  =  1.0
#      var(7)  =  0.14285714285714285
# Nível: 9
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 0 (-18) rows, 0 (-9) columns and 0 (-90) elements
# Clp0000I Optimal - objective value 7
# Coin0511I After Postsolve, objective 7, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 7 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 7.0
# Solução:
#      var(1)  =  1.0
# Nível: 9
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 9.3957091 Primal inf 0.94544957 (4) Dual inf 1.5277778e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value -25
# Clp0032I PrimalInfeasible objective -25 - 4 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 8
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 11.301855 Primal inf 0.85852379 (4) Dual inf 1.4027778e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value -14
# Clp0032I PrimalInfeasible objective -14 - 4 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 7
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 12.498326 Primal inf 1.0736307 (4) Dual inf 1.5555556e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value -5
# Clp0032I PrimalInfeasible objective -5 - 5 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 6
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 13.582846 Primal inf 0.9122767 (4) Dual inf 1.5e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value 9
# Clp0032I PrimalInfeasible objective 9 - 3 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 5
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 12.986294 Primal inf 1.2002066 (5) Dual inf 3.2916667e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value 4.3333333
# Clp0032I PrimalInfeasible objective 4.333333333 - 6 iterations time 0.002
# Status = OptimizationStatus.INFEASIBLE
# Nível: 4
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 14.320082 Primal inf 0.76342585 (4) Dual inf 1.1111111e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value 8.8817842e-15
# Clp0032I PrimalInfeasible objective 8.881784197e-15 - 5 iterations time 0.002
# Status = OptimizationStatus.INFEASIBLE
# Nível: 2
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 8 (-3) rows, 7 (-2) columns and 56 (-27) elements
# Clp1000I sum of infeasibilities 0 - average 0, 1 fixed columns
# Coin0506I Presolve 7 (-1) rows, 6 (-1) columns and 42 (-14) elements
# Clp0006I 0  Obj 12.540372 Dual inf 4900 (6)
# Clp0029I End of values pass after 6 iterations
# Clp0000I Optimal - objective value 12.540541
# Clp0000I Optimal - objective value 12.540541
# Coin0511I After Postsolve, objective 12.540541, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 12.540541
# Clp0000I Optimal - objective value 12.540541
# Clp0000I Optimal - objective value 12.540541
# Clp0000I Optimal - objective value 12.540541
# Coin0511I After Postsolve, objective 12.540541, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 12.54054054 - 0 iterations time 0.002, Presolve 0.00
# Solução ótima
# Valor da solução: 12.54054054054054
# Solução:
#      var(1)  =  0.027027027027026928
#      var(3)  =  1.0
#      var(8)  =  0.5945945945945947
# Nível: 3
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 8 (-4) rows, 6 (-3) columns and 48 (-36) elements
# Clp1000I sum of infeasibilities 0 - average 0, 1 fixed columns
# Coin0506I Presolve 6 (-2) rows, 5 (-1) columns and 30 (-18) elements
# Clp0006I 0  Obj 12.368375 Dual inf 3485.7143 (5)
# Clp0029I End of values pass after 5 iterations
# Clp0000I Optimal - objective value 12.368421
# Clp0000I Optimal - objective value 12.368421
# Coin0511I After Postsolve, objective 12.368421, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 12.368421
# Clp0000I Optimal - objective value 12.368421
# Clp0000I Optimal - objective value 12.368421
# Clp0000I Optimal - objective value 12.368421
# Coin0511I After Postsolve, objective 12.368421, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 12.36842105 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 12.368421052631579
# Solução:
#      var(0)  =  0.2894736842105263
#      var(1)  =  0.39473684210526316
#      var(3)  =  1.0
# Nível: 4
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 8 (-5) rows, 5 (-4) columns and 40 (-45) elements
# Clp1000I sum of infeasibilities 0 - average 0, 1 fixed columns
# Coin0506I Presolve 5 (-3) rows, 4 (-1) columns and 20 (-20) elements
# Clp0006I 0  Obj 11.3076 Dual inf 3100 (4)
# Clp0029I End of values pass after 4 iterations
# Clp0000I Optimal - objective value 11.307692
# Clp0000I Optimal - objective value 11.307692
# Coin0511I After Postsolve, objective 11.307692, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 11.307692
# Clp0000I Optimal - objective value 11.307692
# Clp0000I Optimal - objective value 11.307692
# Clp0000I Optimal - objective value 11.307692
# Coin0511I After Postsolve, objective 11.307692, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 11.30769231 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 11.307692307692307
# Solução:
#      var(3)  =  1.0
#      var(6)  =  0.423076923076923
#      var(7)  =  0.23076923076923098
# Nível: 5
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-7) rows, 4 (-5) columns and 28 (-58) elements
# Clp1000I sum of infeasibilities 0 - average 0, 0 fixed columns
# Coin0506I Presolve 5 (-2) rows, 4 (0) columns and 20 (-8) elements
# Clp0006I 0  Obj 11.132053 Dual inf 2885.7143 (4)
# Clp0029I End of values pass after 4 iterations
# Clp0000I Optimal - objective value 11.132075
# Clp0000I Optimal - objective value 11.132075
# Coin0511I After Postsolve, objective 11.132075, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 11.132075
# Clp0000I Optimal - objective value 11.132075
# Clp0000I Optimal - objective value 11.132075
# Clp0000I Optimal - objective value 11.132075
# Coin0511I After Postsolve, objective 11.132075, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 11.13207547 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 11.132075471698116
# Solução:
#      var(0)  =  0.20754716981132082
#      var(3)  =  1.0
#      var(7)  =  0.5660377358490567
# Nível: 6
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-8) rows, 3 (-6) columns and 21 (-66) elements
# Clp1000I sum of infeasibilities 0 - average 0, 1 fixed columns
# Coin0506I Presolve 4 (-3) rows, 2 (-1) columns and 8 (-13) elements
# Clp0006I 0  Obj 10.599989 Dual inf 789.89795 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0000I Optimal - objective value 10.6
# Clp0000I Optimal - objective value 10.6
# Coin0511I After Postsolve, objective 10.6, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 10.6
# Clp0000I Optimal - objective value 10.6
# Clp0000I Optimal - objective value 10.6
# Clp0000I Optimal - objective value 10.6
# Coin0511I After Postsolve, objective 10.6, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 10.6 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 10.600000000000001
# Solução:
#      var(3)  =  1.0
#      var(5)  =  0.6000000000000001
# Nível: 7
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-9) rows, 2 (-7) columns and 14 (-74) elements
# Clp1000I sum of infeasibilities 3.77304e-10 - average 5.39005e-11, 1 fixed columns
# Coin0506I Presolve 0 (-7) rows, 0 (-2) columns and 0 (-14) elements
# Clp0000I Optimal - objective value 10
# Clp0000I Optimal - objective value 10
# Coin0511I After Postsolve, objective 10, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 10
# Clp0000I Optimal - objective value 10
# Clp0000I Optimal - objective value 10
# Clp0000I Optimal - objective value 10
# Coin0511I After Postsolve, objective 10, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 10 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 10.0
# Solução:
#      var(0)  =  0.33333333333333337
#      var(3)  =  1.0
# Nível: 8
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 0 (-17) rows, 0 (-9) columns and 0 (-89) elements
# Clp0000I Optimal - objective value 9.7
# Coin0511I After Postsolve, objective 9.7, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 9.7 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 9.7
# Solução:
#      var(3)  =  1.0
#      var(4)  =  0.3
# Nível: 9
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 0 (-18) rows, 0 (-9) columns and 0 (-90) elements
# Clp0000I Optimal - objective value 7
# Coin0511I After Postsolve, objective 7, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 7 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 7.0
# Solução:
#      var(3)  =  1.0
# Nível: 9
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 13.722216 Primal inf 0.94862264 (4) Dual inf 1.2555556e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value -33
# Clp0032I PrimalInfeasible objective -33 - 5 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 8
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 14.528302 Primal inf 0.63395926 (3) Dual inf 4e+11 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value 4
# Status = OptimizationStatus.INFEASIBLE
# Nível: 7
# Clp0032I PrimalInfeasible objective 4 - 7 iterations time 0.002, Idiot 0.00
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 12.379381 Primal inf 0.39670461 (4) Dual inf 5.3333333e+11 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value -1
# Clp0032I PrimalInfeasible objective -1 - 5 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 6
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 10.683417 Primal inf 0.24120303 (3) Dual inf 6.6666667e+11 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value 7.4
# Clp0032I PrimalInfeasible objective 7.4 - 7 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 5
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 13.886214 Primal inf 0.57680454 (4) Dual inf 7.4444444e+11 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value -6
# Clp0032I PrimalInfeasible objective -6 - 5 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 4
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 13.088372 Primal inf 0.46511328 (3) Dual inf 4.4444445e+11 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value 6.8
# Clp0032I PrimalInfeasible objective 6.8 - 12 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 3
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 14.987057 Primal inf 0.49216743 (4) Dual inf 6.4444444e+11 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value 2
# Clp0032I PrimalInfeasible objective 2 - 4 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 1
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 8 (-2) rows, 8 (-1) columns and 64 (-18) elements
# Clp1000I sum of infeasibilities 0 - average 0, 4 fixed columns
# Coin0506I Presolve 6 (-2) rows, 4 (-4) columns and 24 (-40) elements
# Clp0006I 0  Obj 13.486416 Dual inf 3200 (4)
# Clp0029I End of values pass after 4 iterations
# Clp0000I Optimal - objective value 13.486486
# Clp0000I Optimal - objective value 13.486486
# Coin0511I After Postsolve, objective 13.486486, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 13.486486
# Clp0000I Optimal - objective value 13.486486
# Clp0000I Optimal - objective value 13.486486
# Clp0000I Optimal - objective value 13.486486
# Coin0511I After Postsolve, objective 13.486486, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 13.48648649 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 13.486486486486486
# Solução:
#      var(1)  =  0.3243243243243243
#      var(2)  =  1.0
#      var(8)  =  0.13513513513513514
# Nível: 2
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 8 (-3) rows, 7 (-2) columns and 56 (-27) elements
# Clp1000I sum of infeasibilities 4.52604e-07 - average 5.65755e-08, 4 fixed columns
# Coin0506I Presolve 6 (-2) rows, 3 (-4) columns and 18 (-38) elements
# Clp0006I 0  Obj 11.999835 Dual inf 2100 (3)
# Clp0029I End of values pass after 3 iterations
# Clp0000I Optimal - objective value 12
# Clp0000I Optimal - objective value 12
# Coin0511I After Postsolve, objective 12, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 12
# Clp0000I Optimal - objective value 12
# Clp0000I Optimal - objective value 12
# Clp0000I Optimal - objective value 12
# Coin0511I After Postsolve, objective 12, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 12 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 12.0
# Solução:
#      var(2)  =  1.0
#      var(7)  =  0.5
# Nível: 3
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 8 (-4) rows, 6 (-3) columns and 48 (-36) elements
# Clp1000I sum of infeasibilities 0 - average 0, 3 fixed columns
# Coin0506I Presolve 5 (-3) rows, 3 (-3) columns and 15 (-33) elements
# Clp0006I 0  Obj 11.799937 Dual inf 2571.4286 (3)
# Clp0029I End of values pass after 3 iterations
# Clp0000I Optimal - objective value 11.8
# Clp0000I Optimal - objective value 11.8
# Coin0511I After Postsolve, objective 11.8, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 11.8
# Clp0000I Optimal - objective value 11.8
# Clp0000I Optimal - objective value 11.8
# Clp0000I Optimal - objective value 11.8
# Coin0511I After Postsolve, objective 11.8, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 11.8 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 11.8
# Solução:
#      var(2)  =  1.0
#      var(8)  =  0.2
# Nível: 4
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 8 (-5) rows, 5 (-4) columns and 40 (-45) elements
# Clp1000I sum of infeasibilities 0 - average 0, 3 fixed columns
# Coin0506I Presolve 3 (-5) rows, 2 (-3) columns and 6 (-34) elements
# Clp0006I 0  Obj 11.333293 Dual inf 1400 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0000I Optimal - objective value 11.333333
# Clp0000I Optimal - objective value 11.333333
# Coin0511I After Postsolve, objective 11.333333, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 11.333333
# Clp0000I Optimal - objective value 11.333333
# Clp0000I Optimal - objective value 11.333333
# Clp0000I Optimal - objective value 11.333333
# Coin0511I After Postsolve, objective 11.333333, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 11.33333333 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 11.333333333333334
# Solução:
#      var(2)  =  1.0
#      var(6)  =  0.16666666666666666
# Nível: 5
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-7) rows, 4 (-5) columns and 28 (-58) elements
# Clp1000I sum of infeasibilities 0 - average 0, 3 fixed columns
# Coin0506I Presolve 0 (-7) rows, 0 (-4) columns and 0 (-28) elements
# Clp0000I Optimal - objective value 11.2
# Clp0000I Optimal - objective value 11.2
# Coin0511I After Postsolve, objective 11.2, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 11.2
# Clp0000I Optimal - objective value 11.2
# Clp0000I Optimal - objective value 11.2
# Clp0000I Optimal - objective value 11.2
# Coin0511I After Postsolve, objective 11.2, infeasibilities - dual 0 (0), primal 0 (0)
# Solução ótima
# Valor da solução: 11.2
# Solução:
#      var(2)  =  1.0
#      var(5)  =  0.2
# Clp0032I Optimal objective 11.2 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Nível: 6
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-8) rows, 3 (-6) columns and 21 (-66) elements
# Clp1000I sum of infeasibilities 1.67938e-09 - average 2.39911e-10, 0 fixed columns
# Coin0506I Presolve 5 (-2) rows, 3 (0) columns and 15 (-6) elements
# Clp0006I 0  Obj 10.999994 Dual inf 1428.1077 (3)
# Clp0029I End of values pass after 3 iterations
# Clp0000I Optimal - objective value 11
# Clp0000I Optimal - objective value 11
# Coin0511I After Postsolve, objective 11, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 11
# Clp0000I Optimal - objective value 11
# Clp0000I Optimal - objective value 11
# Clp0000I Optimal - objective value 11
# Coin0511I After Postsolve, objective 11, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 11 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 11.0
# Solução:
#      var(0)  =  0.11111111111111113
#      var(2)  =  1.0
# Nível: 7
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 7 (-9) rows, 2 (-7) columns and 14 (-74) elements
# Clp1000I sum of infeasibilities 0 - average 0, 0 fixed columns
# Coin0506I Presolve 5 (-2) rows, 2 (0) columns and 10 (-4) elements
# Clp0006I 0  Obj 10.999931 Dual inf 948.07407 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0000I Optimal - objective value 11
# Clp0000I Optimal - objective value 11
# Coin0511I After Postsolve, objective 11, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0006I 0  Obj 11
# Clp0000I Optimal - objective value 11
# Clp0000I Optimal - objective value 11
# Clp0000I Optimal - objective value 11
# Coin0511I After Postsolve, objective 11, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 11 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 11.0
# Solução:
#      var(2)  =  1.0
#      var(3)  =  0.14285714285714288
# Nível: 8
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 0 (-17) rows, 0 (-9) columns and 0 (-89) elements
# Clp0000I Optimal - objective value 10.9
# Coin0511I After Postsolve, objective 10.9, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 10.9 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 10.9
# Solução:
#      var(2)  =  1.0
#      var(4)  =  0.1
# Nível: 9
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0506I Presolve 0 (-18) rows, 0 (-9) columns and 0 (-90) elements
# Clp0000I Optimal - objective value 10
# Coin0511I After Postsolve, objective 10, infeasibilities - dual 0 (0), primal 0 (0)
# Clp0032I Optimal objective 10 - 0 iterations time 0.002, Presolve 0.00, Idiot 0.00
# Solução ótima
# Valor da solução: 10.0
# Solução:
#      var(2)  =  1.0
# Nível: 9
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 15.553118 Primal inf 1.1624904 (4) Dual inf 1.5666667e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value -44
# Clp0032I PrimalInfeasible objective -44 - 5 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 8
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 15.426415 Primal inf 0.63395926 (3) Dual inf 4e+11 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value 5
# Clp0032I PrimalInfeasible objective 5 - 7 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 7
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 16.565836 Primal inf 0.82561978 (3) Dual inf 2e+11 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value -37
# Clp0032I PrimalInfeasible objective -37 - 6 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 6
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 14.176581 Primal inf 0.82989369 (5) Dual inf 2.4694444e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value -11
# Clp0032I PrimalInfeasible objective -11 - 9 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 5
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 15.831568 Primal inf 0.87972649 (5) Dual inf 2.3888889e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Status = OptimizationStatus.INFEASIBLE
# Nível: 4
# Clp0001I Primal infeasible - objective value 12.222222
# Clp0032I PrimalInfeasible objective 12.22222222 - 2 iterations time 0.002, Idiot 0.00
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 16.41239 Primal inf 0.99935186 (6) Dual inf 4.025e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value 13.571429
# Status = OptimizationStatus.INFEASIBLE
# Nível: 3
# Clp0032I PrimalInfeasible objective 13.57142857 - 3 iterations time 0.002, Idiot 0.00
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 12.638472 Primal inf 0.70628155 (4) Dual inf 1.1944444e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Clp0001I Primal infeasible - objective value -22
# Clp0032I PrimalInfeasible objective -22 - 7 iterations time 0.002, Idiot 0.00
# Status = OptimizationStatus.INFEASIBLE
# Nível: 2
# Starting solution of the Linear programming problem using Primal Simplex
#
# Coin0507I Presolve determined that the problem was infeasible with tolerance of 1e-08
# Clp3003W Analysis indicates model infeasible or unbounded
# Clp0006I 0  Obj 15.362158 Primal inf 0.68450255 (4) Dual inf 1.1666667e+12 (2)
# Clp0029I End of values pass after 2 iterations
# Status = OptimizationStatus.INFEASIBLE
# Melhor solução encontrada:
#      var(0)  =  0.0
#      var(1)  =  0.0
#      var(2)  =  1.0
# Clp0001I Primal infeasible - objective value -1
# Clp0032I PrimalInfeasible objective -1 - 4 iterations time 0.002, Idiot 0.00
#      var(3)  =  0.0
#      var(4)  =  0.0
#      var(5)  =  0.0
#      var(6)  =  0.0
#      var(7)  =  0.0
#      var(8)  =  0.0
# Valor da solução: 10.0
